# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("batting_data")

# %%
data
# Out:
#     Unnamed: 0             PLAYER  Mat.x  Inns.x  NO  Runs.x  HS  Avg.x   BF  \
# 0            0        Aaron Finch     10       9   1     134  46  16.75  100
# 1            1     AB de Villiers     12      11   2     480  90  53.33  275
# 2            2    Abhishek Sharma      3       3   2      63  46  63.00   33
# 3            3     Ajinkya Rahane     15      14   1     370  65  28.46  313
# 4            4         Alex Hales      6       6   0     148  45  24.66  118
# ..         ...                ...    ...     ...  ..     ...  ..    ...  ...
# 95          95        Virat Kohli     14      14   3     530  92  48.18  381
# 96          96  Washington Sundar      7       6   3      65  35  21.66   38
# 97          97    Wriddhiman Saha     11      10   2     122  35  15.25  102
# 98          98       Yusuf Pathan     15      13   4     260  45  28.88  200
# 99          99       Yuvraj Singh      8       6   0      65  20  10.83   73
#
#       SR.x  X100  X50  X4s  X6s
# ...

# %%
data.drop(columns=["Unnamed: 0"],axis=1,inplace=True)

# %%
data
# Out:
#                PLAYER  Mat.x  Inns.x  NO  Runs.x  HS  Avg.x   BF    SR.x  \
# 0         Aaron Finch     10       9   1     134  46  16.75  100  134.00
# 1      AB de Villiers     12      11   2     480  90  53.33  275  174.54
# 2     Abhishek Sharma      3       3   2      63  46  63.00   33  190.90
# 3      Ajinkya Rahane     15      14   1     370  65  28.46  313  118.21
# 4          Alex Hales      6       6   0     148  45  24.66  118  125.42
# ..                ...    ...     ...  ..     ...  ..    ...  ...     ...
# 95        Virat Kohli     14      14   3     530  92  48.18  381  139.10
# 96  Washington Sundar      7       6   3      65  35  21.66   38  171.05
# 97    Wriddhiman Saha     11      10   2     122  35  15.25  102  119.60
# 98       Yusuf Pathan     15      13   4     260  45  28.88  200  130.00
# 99       Yuvraj Singh      8       6   0      65  20  10.83   73   89.04
#
#     X100  X50  X4s  X6s
# 0      0    0    6    8
# 1      0    6   39   30
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PLAYER  100 non-null    object
#  1   Mat.x   100 non-null    int64
#  2   Inns.x  100 non-null    int64
#  3   NO      100 non-null    int64
#  4   Runs.x  100 non-null    int64
#  5   HS      100 non-null    int64
#  6   Avg.x   97 non-null     float64
#  7   BF      100 non-null    int64
#  8   SR.x    100 non-null    float64
#  9   X100    100 non-null    int64
#  10  X50     100 non-null    int64
#  11  X4s     100 non-null    int64
#  12  X6s     100 non-null    int64
# dtypes: float64(2), int64(10), object(1)
# memory usage: 10.3+ KB

# %%
data.describe()
# Out:
#             Mat.x      Inns.x          NO      Runs.x          HS      Avg.x  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  97.000000
# mean    10.420000    8.600000    1.790000  189.260000   47.410000  25.126289
# std      4.472542    4.572646    1.683521  182.454235   27.987044  14.870974
# min      1.000000    1.000000    0.000000   13.000000    7.000000   3.000000
# 25%      6.000000    4.000000    1.000000   50.000000   25.500000  13.750000
# 50%     11.000000    8.000000    1.000000  120.000000   44.500000  22.800000
# 75%     14.000000   13.000000    3.000000  284.500000   65.000000  32.400000
# max     17.000000   17.000000    9.000000  735.000000  128.000000  75.830000
#
#                BF        SR.x        X100         X50         X4s         X6s
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean   135.890000  133.162000    0.050000    1.010000   16.390000    8.680000
# ...

# %%
data.groupby("Avg.x").size()
# Out:
# Avg.x
# 3.00     1
# 4.33     1
# 5.33     1
# 5.66     1
# 6.50     1
#         ..
# 54.80    1
# 54.91    1
# 60.00    1
# 63.00    1
# 75.83    1
# Length: 93, dtype: int64

# %%
data[]

# %%
numcols=data.select_dtypes(include="float64","int64").columns
numcols
# Out:
# Index(['Mat.x', 'Inns.x', 'NO', 'Runs.x', 'HS', 'Avg.x', 'BF', 'SR.x', 'X100',
#        'X50', 'X4s', 'X6s'],
#       dtype='object')

# %%
fig, axes = plt.subplots(ncols=4, nrows=3, figsize=(10,7))
axes = axes.flat
for index, column in enumerate(numcols):
    sns.boxplot(
        data=data,
        x=column,
        ax=axes[index]
                )
    axes[index].set_xlabel('')
    axes[index].set_title(column)
plt.suptitle('Finding Outliers', fontsize=20)
plt.tight_layout()
plt.show()

# %%
colname=data.select_dtypes(["int64","float64"]).columns
colname
# Out:
# Index(['Mat.x', 'Inns.x', 'NO', 'Runs.x', 'HS', 'Avg.x', 'BF', 'SR.x', 'X100',
#        'X50', 'X4s', 'X6s'],
#       dtype='object')

# %%
from scipy.stats import skew
skew(data["X6s"])
# Out:
# 1.3822793353308578

# %%
for i in data[colname]:
    print(i)
    print(skew(data[i]))
    plt.figure()
    sns.distplot(data[i])
    plt.show()
# Out:
# Mat.x
# -0.3003186679647856
# Inns.x
# 0.17290421302378436
# NO
# 1.4184719052388253
# Runs.x
# 1.1480671806491358
# HS
# 0.6383050646976142
# Avg.x
# nan
# BF
# 1.0530229820209447
# SR.x
# 1.195075152562492
# X100
# 5.687969318682978
# X50
# 1.9369088303700113
# X4s
# 1.3412599943131716
# X6s
# 1.3822793353308578

# %%
sns.pairplot(data)
plt.show()

# %%
plt.figure(fi)
